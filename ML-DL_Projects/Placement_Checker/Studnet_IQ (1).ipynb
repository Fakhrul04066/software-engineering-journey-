# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
df= pd.read_csv('/content/student_placement_data.csv')

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# (100, 4)

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa   iq placement
# 0  8.20   73        No
# 1  8.71  101       Yes
# 2  6.12   83        No
# 3  8.38  139       Yes
# 4  5.43  124        No

# %%
df['placement_num'] = df['placement'].map({'Yes': 1, 'No': 0})

plt.scatter(
    df['cgpa'],
    df['iq'],
    c=df['placement_num'],
    cmap='viridis'
)

plt.xlabel("CGPA")
plt.ylabel("IQ")
plt.show()

# %%
x= df.iloc[:,0:2]
y= df.iloc[:,-1]

# %%
x
# Out:
#     cgpa   iq
# 0   8.20   73
# 1   8.71  101
# 2   6.12   83
# 3   8.38  139
# 4   5.43  124
# ..   ...  ...
# 95  9.53  112
# 96  5.35  100
# 97  6.39  132
# 98  6.07   86
# 99  8.62  143
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     0
# 1     1
# 2     0
# 3     1
# 4     0
#      ..
# 95    1
# 96    0
# 97    0
# 98    0
# 99    1
# Name: placement_num, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa   iq
# 36  6.10  111
# 15  5.51  118
# 65  9.86   92
# 81  8.30  140
# 24  5.23   99
# ..   ...  ...
# 62  5.56  125
# 96  5.35  100
# 75  9.39  109
# 20  5.39  107
# 39  9.03  121
#
# [90 rows x 2 columns]

# %%
y_test
# Out:
# 60    1
# 10    0
# 44    0
# 19    0
# 70    0
# 76    0
# 45    0
# 82    0
# 32    0
# 4     0
# Name: placement_num, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.9959675 ,  0.01997669],
#        [-1.38492002,  0.3196271 ],
#        [ 1.48278077, -0.79336013],
#        [ 0.45436393,  1.26138553],
#        [-1.56950766, -0.49370972],
#        [-1.40469727,  0.1483983 ],
#        [-0.98278267,  0.1055911 ],
#        [ 0.96857235,  1.17577112],
#        [ 1.29160072,  1.34699993],
#        [ 0.05222658,  1.43261433],
#        [-0.96300542, -0.53651692],
#        [-1.06848407,  1.21857833],
#        [-0.9102661 ,  1.30419273],
#        [ 0.7773923 , -0.87897453],
#        [-0.2773942 ,  1.09015672],
#        [-0.83774953, -0.57932412],
#        [ 0.38843978, -1.60669695],
#        [ 0.62576674,  0.44804871],
#        [-0.04665965, -1.17862494],
#        [ 1.01471926,  1.64665034],
#        [-1.22010963, -0.87897453],
#        [ 1.43663386,  0.1055911 ],
#        [ 0.02585692,  1.26138553],
#        [-0.80478745,  0.91892792],
#        [ 0.59280466, -1.34985374],
#        [-0.4026501 , -0.53651692],
#        [ 1.56848217, -1.00739613],
#        [ 0.66532123,  1.38980713],
#        [ 0.88946336,  0.57647031],
#        [-1.43765935,  0.91892792],
#        [ 1.30478555,  1.51822873],
#        [ 1.14656757, -0.10844491],
#        [-0.46857425,  0.74769911],
#        [ 0.50710326,  1.21857833],
#        [-0.46198184,  0.79050631],
#        [ 0.77079988, -0.66493852],
#        [-0.31035628,  1.43261433],
#        [ 0.77079988, -1.13581774],
#        [ 0.80376196, -1.05020333],
#        [ 0.26318388,  1.30419273],
#        [ 0.37525495,  0.2340127 ],
#        [-0.65316189, -1.64950415],
#        [-1.18714755,  0.1912055 ],
#        [-1.69476355,  1.68945754],
#        [ 1.45641111,  1.21857833],
#        [-1.20033238, -1.73511855],
#        [ 0.68509848,  1.17577112],
#        [-0.98278267, -1.17862494],
#        [ 1.17293723, -1.30704654],
#        [ 0.18407489, -1.39266094],
#        [-1.35195794,  0.2340127 ],
#        [-1.02233716,  0.96173512],
#        [ 1.56188976,  0.2768199 ],
#        [-0.96300542, -1.56388975],
#        [-0.04006724, -1.26423934],
#        [ 1.05427375, -1.43546814],
#        [ 0.52028809, -1.13581774],
#        [-0.83115711,  1.30419273],
#        [ 1.11360549, -1.69231135],
#        [ 0.03904175, -0.40809532],
#        [-1.61565457, -1.26423934],
#        [ 0.57961983,  0.1055911 ],
#        [ 1.26523105,  0.06278389],
#        [ 1.10042066, -1.22143214],
#        [ 0.2697763 , -1.52108255],
#        [ 1.05427375,  1.00454232],
#        [-1.00255992,  1.00454232],
#        [-1.64861665,  1.26138553],
#        [-0.33672594,  0.70489191],
#        [ 0.75102264,  0.1055911 ],
#        [-1.18055514,  0.3196271 ],
#        [-1.52995316, -1.39266094],
#        [ 0.28296113, -0.92178173],
#        [-0.23124729, -0.40809532],
#        [-0.80478745, -0.57932412],
#        [ 1.15315999,  0.57647031],
#        [ 0.83013162, -1.30704654],
#        [ 0.058819  ,  1.13296392],
#        [ 1.42344903, -0.32248092],
#        [ 0.24340663,  0.3624343 ],
#        [-1.01574475, -1.05020333],
#        [ 0.72465297, -0.40809532],
#        [-1.02892958, -0.27967371],
#        [ 1.16634482, -0.02283051],
#        [ 1.1993069 ,  0.2340127 ],
#        [-1.35195794,  0.61927751],
#        [-1.49039867, -0.45090252],
#        [ 1.17293723, -0.06563771],
#        [-1.46402901, -0.15125211],
#        [ 0.93561027,  0.44804871]])

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.52688051,  1.17577112],
#        [ 0.22362939, -1.73511855],
#        [-0.41583493,  0.74769911],
#        [-1.31240345,  0.3196271 ],
#        [-0.4883515 , -0.87897453],
#        [-0.93004334, -0.45090252],
#        [-1.25307171, -1.00739613],
#        [-1.17396272,  1.13296392],
#        [ 0.28955354, -0.83616733],
#        [-1.43765935,  0.57647031]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf= LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf , legend=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plot_decision_regions(x_train,y_train.values,clf=clf , legend=2)
#
# NameError: name 'plot_decision_regions' is not defined
